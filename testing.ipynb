# %%
import os
import re
import math
import requests
from lxml import html
import cv2
import mediapipe as mp
from mediapipe.tasks import python
from mediapipe.tasks.python import vision
from imutils.video import FileVideoStream


from sign_utils import *
import os
from tqdm import tqdm

# %% [markdown]
# ## Crawl TID Sözlük

# %%
def groupById(vids: list):
    GROUPS = {}
    curr_id = ''
    for vid in vids:
        _,_,_id,_,fname = vid.split('/')
        if _id != curr_id:
            GROUPS[_id] = [vid]
            curr_id = _id
        else: GROUPS[curr_id].append(vid)
    return GROUPS

# %%
from urllib.request import urlopen
from tqdm import tqdm

CHARS = ['A', 'B', 'C', 'Ç', 'D', 'E', 'F', 'G', 'H', 'I', 'İ', 'J', 'K', 'L', 'M', 'N', 'O', 'Ö', 'P', 'R', 'S', 'Ş', 'T', 'U', 'Ü', 'V', 'W', 'Y', 'Z']

for char in tqdm(CHARS):
    
    print(f'At {char=}')
    
    page = str(1)
    BASE_URL = 'https://tidsozluk.aile.gov.tr'
    SEARCH_URL = f'https://tidsozluk.aile.gov.tr/tr/Alfabetik/Arama/{char}?p={page}'
    
    HTML = html.fromstring(requests.get(SEARCH_URL).content)
    PAGES = math.ceil(int(HTML.xpath('//div[contains(@id, "rezults_summ")]//b/text()')[0]) / 10)
    
    for page in range(1, PAGES+1):    
        
        print(f'At {page=}')
        
        if page > 1:
            HTML = html.fromstring(requests.get(f'https://tidsozluk.aile.gov.tr/tr/Alfabetik/Arama/{char}?p={page}').content)
    
        LEXICON = [res.xpath('//h3/text()') for res in HTML.xpath(ROW_XPATH)][0]
        
        VIDEOS = [ re.sub('0\.1','0.5', vid) for vid in [res.xpath('//source/@src') for res in HTML.xpath(ROW_XPATH)][0]]
    
        for name, vids in tqdm(list(zip(LEXICON,list(groupById(VIDEOS).values())))):
            
            for idx, vid in enumerate(vids):
                
                f = urlopen(BASE_URL+vid)
                with open(f'../data/corpus/{name.upper()}_{idx}.mp4', 'wb') as code:
                    code.write(f.read())
# Out:
#   0%|          | 0/29 [00:00<?, ?it/s]
# At char='A'
# At page=1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/3n/htgy5xms739d5j9z9r7lw1540000gn/T/ipykernel_1848/2177210914.py in <module>
#      22             HTML = html.fromstring(requests.get(f'https://tidsozluk.aile.gov.tr/tr/Alfabetik/Arama/{char}?p={page}').content)
#      23
# ---> 24         LEXICON = [res.xpath('//h3/text()') for res in HTML.xpath(ROW_XPATH)][0]
#      25
#      26         VIDEOS = [ re.sub('0\.1','0.5', vid) for vid in [res.xpath('//source/@src') for res in HTML.xpath(ROW_XPATH)][0]]
#
# NameError: name 'ROW_XPATH' is not defined

# %% [markdown]
# ## Infer Pose Estimation

# %%
mp_drawing = mp.solutions.drawing_utils
mp_holistic = mp.solutions.holistic

INFO = {}

for v in tqdm(os.listdir('data/corpus/')[:10]):
    
    #camera = cv2.VideoCapture('data/corpus/'+ v)
    fvs = FileVideoStream('data/corpus/'+ v).start()
    
    fname = v[:-4]
        
    logs_left = None
    move_left = None
    logs_right = None
    move_right = None
    
    phonology_left = SignLanguagePhonology(hand='left')
    phonology_right = SignLanguagePhonology(hand='right')

    window_size = 5
    view_window = 100

    hand_relation = TwoHandedPhonology()
    
    frame = fvs.read()


    with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
        
        while fvs.more():

            image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            
            results = holistic.process(image)

            logs_right = phonology_right.getJointInfo(
                results.right_hand_landmarks, results.pose_landmarks, [ 'LOCATION', 'ORIENTATION', 'FINGER_SELECTION', 'MOVEMENT'])
            logs_left = phonology_left.getJointInfo(
                results.left_hand_landmarks, results.pose_landmarks, [ 'LOCATION', 'ORIENTATION', 'FINGER_SELECTION', 'MOVEMENT'])

            move_left = phonology_left.getMovementInformation(
                    view_window, window_size, ['Center_Diff', 'Center_MovAVG_x', 'Center_MovAVG_y', 'Center_MovAVG_z',
                                                'INDEX_FINGER', 'MIDDLE_FINGER', 'RING_FINGER', 'PINKY', 'SWITCH', 'LSE_x', 'LSE_y'])
            move_right = phonology_right.getMovementInformation(
                    view_window, window_size, ['Center_Diff', 'Center_MovAVG_x', 'Center_MovAVG_y', 'Center_MovAVG_z',
                                                'INDEX_FINGER', 'MIDDLE_FINGER', 'RING_FINGER', 'PINKY', 'SWITCH', 'LSE_x', 'LSE_y'])

            #hand_relation.findTemporalAlignment(
            #        phonology_left, phonology_right, view_window, window_size, metrics)

            #ss, frame = camera.read()
            frame = fvs.read()
            

            
    INFO[fname] = { }
    
    INFO[fname]['left_log'] = phonology_left.INFO_MEMORY
    INFO[fname]['left_move'] = move_left
    INFO[fname]['right_log'] = phonology_right.INFO_MEMORY
    INFO[fname]['right_move'] = move_right
# Out:
# 100%|██████████| 10/10 [00:32<00:00,  3.24s/it]

# %% [markdown]
# ## Infer Pose Estimation

# %%
import pickle
import os
from collections import defaultdict
class LexicalClassification():
    
    def __init__(self):
        
        # TODO: EXPERIMENTS
        # - POSE + DTW
        # - PRIOR_FEATS + DTW
        # - PROPOSED_FEATS + DTW
        
        # EXPERIMENTS: DTW TYPES
        # - WEIGHTED DTW
                
        self.LEXICON = []
        self.VECTORS = []
        
        self.importLexicon(INFO_TYPE='feat', METRICS=None)
        
    def importLexicon(self, INFO_TYPE: str, METRICS: list[str]):
        
        file = os.listdir('data/vectors/feats/')[-1]
                
        ITEMS = pickle.loads(open('data/vectors/feats/'+file, 'rb').read())
        
        for label, INFO in tqdm(ITEMS.items()):
            
            self.LEXICON.append(label)
            self.VECTORS.append(self.processVectors(INFO, INFO_TYPE, METRICS))

    def processVectors(self, INFO, INFO_TYPE, METRICS):
       
       # SET INFORMATION:
       # - LOCATION: Signal to MAJOR LOCATIONS ( MAJOR LOCATION CONSTRAINT)
       # - ORIENTATION: Signal to 6 ORIENTATION (DIFF RELATIVE SCORE TO 3 PAIRS)
       # - FINGER_SELECTION: Signal to 5 FINGER APERTURES (TODO: SHOULD ADD SELECTION/CURVE FEATS) ( SELECTED FINGER CONSTRAINT)
       # - MOVEMENT: Signal to 2 MOVEMENT FEATS ( PATH: (0,1), APERATURE: (0,1) )
       
       
       VECTORS = self.generateVector(INFO['right_log'], 'right')
       VECTORS.update(self.generateVector(INFO['left_log'], 'left'))
       
       return VECTORS
       
    def generateVector(self, points, hand):
        
        FEAT_DICT = defaultdict(list)
        
        for point in points:
        
            for location, (_, proximity) in point['LOCATION'].items():
                
                FEAT_DICT[f"{location}_PROXIMITY_{hand.upper()}"].append(proximity)

            # FIXME: UNNECESSARY DICT
            for orient,rotation in zip(['PALM/BACK', 'TIPS/WRIST', 'URNAL/RADIAL' ],point['ORIENTATION']['ORIENTATION']):
                
                FEAT_DICT[f"{orient}_PROXIMITY_{hand.upper()}"].append(list(rotation)[-1])   
            
            for hand_dict in point['FINGER_SELECTION']:
                
                ff = 'FINGER' if 'FINGER' in hand_dict.keys() else 'finger'                 
                
                FEAT_DICT[f"{hand_dict[ff]}_ANGLE_{hand.upper()}"].append(hand_dict['ANGLE_1' if hand_dict[ff] != 'THUMB' else 'ANGLE_0'])
            
                FEAT_DICT[f"{hand_dict[ff]}_SELECTION_{hand.upper()}"].append(1 if hand_dict['is_selected'] else 0)
                
                FEAT_DICT[f"{hand_dict[ff]}_CURVED_{hand.upper()}"].append(1 if hand_dict['is_curved'] else 0)

            for feats in point['MOVEMENT']:
                            
                feat_name, val = list(feats.items())[0]
                
                FEAT_DICT[f"{feat_name}_MOVEMENT_{hand.upper()}"].append(val[-1])
                
        
        FEAT_DICT = {
            FEATURE: pd.Series(VALS)  for FEATURE, VALS in FEAT_DICT.items()
        }
        
        return FEAT_DICT

CLS = LexicalClassification()
# Out:
# 100%|██████████| 2500/2500 [00:08<00:00, 288.27it/s]

# %%
KEY_SET = set(['CHEST_PROXIMITY_RIGHT',
 'MOUTH_PROXIMITY_RIGHT',
 'NOSE_PROXIMITY_RIGHT',
 'EAR_PROXIMITY_RIGHT',
 'EYE_PROXIMITY_RIGHT',
 'PALM/BACK_PROXIMITY_RIGHT',
 'TIPS/WRIST_PROXIMITY_RIGHT',
 'URNAL/RADIAL_PROXIMITY_RIGHT',
 'THUMB_ANGLE_RIGHT',
 'THUMB_SELECTION_RIGHT',
 'THUMB_CURVED_RIGHT',
 'INDEX_FINGER_ANGLE_RIGHT',
 'INDEX_FINGER_SELECTION_RIGHT',
 'INDEX_FINGER_CURVED_RIGHT',
 'MIDDLE_FINGER_ANGLE_RIGHT',
 'MIDDLE_FINGER_SELECTION_RIGHT',
 'MIDDLE_FINGER_CURVED_RIGHT',
 'RING_FINGER_ANGLE_RIGHT',
 'RING_FINGER_SELECTION_RIGHT',
 'RING_FINGER_CURVED_RIGHT',
 'PINKY_ANGLE_RIGHT',
 'PINKY_SELECTION_RIGHT',
 'PINKY_CURVED_RIGHT',
 'PATH_MOVEMENT_RIGHT',
 'APERTURE_MOVEMENT_RIGHT',
 'PATH_ANGLE_MOVEMENT_RIGHT',
 'CHEST_PROXIMITY_LEFT',
 'MOUTH_PROXIMITY_LEFT',
 'NOSE_PROXIMITY_LEFT',
 'EAR_PROXIMITY_LEFT',
 'EYE_PROXIMITY_LEFT',
 'PALM/BACK_PROXIMITY_LEFT',
 'TIPS/WRIST_PROXIMITY_LEFT',
 'URNAL/RADIAL_PROXIMITY_LEFT',
 'THUMB_ANGLE_LEFT',
 'THUMB_SELECTION_LEFT',
 'THUMB_CURVED_LEFT',
 'INDEX_FINGER_ANGLE_LEFT',
 'INDEX_FINGER_SELECTION_LEFT',
 'INDEX_FINGER_CURVED_LEFT',
 'MIDDLE_FINGER_ANGLE_LEFT',
 'MIDDLE_FINGER_SELECTION_LEFT',
 'MIDDLE_FINGER_CURVED_LEFT',
 'RING_FINGER_ANGLE_LEFT',
 'RING_FINGER_SELECTION_LEFT',
 'RING_FINGER_CURVED_LEFT',
 'PINKY_ANGLE_LEFT',
 'PINKY_SELECTION_LEFT',
 'PINKY_CURVED_LEFT',
 'PATH_MOVEMENT_LEFT',
 'APERTURE_MOVEMENT_LEFT',
 'PATH_ANGLE_MOVEMENT_LEFT'])

# %%
lexicon_to_idx = dict([(j,i) for i,j in enumerate(CLS.LEXICON)])

# %%
dict(sorted(lexicon_to_idx.items()))
# Out:
# {'ABARTMAK_0': 336,
#  'ABARTMAK_1': 1921,
#  'ABI, AĞABEY_0': 2345,
#  'ABLA_1': 1891,
#  'ABLA_2': 1626,
#  'ACABA_0': 232,
#  'ACEMI _2': 1599,
#  'ACI ÇEKMEK _0': 131,
#  'ACI ÇEKMEK _1': 454,
#  'ACI ÇEKMEK _2': 1649,
#  'ACIL_0': 2474,
#  'ACIMAK_0': 638,
#  'ACIMAK_1': 877,
#  'ACIMAK_2': 754,
#  'ACI_0': 923,
#  'AD, İSIM_0': 1225,
#  'ADA _0': 2224,
#  'ADA _1': 1383,
#  'ADALET_0': 2156,
#  'ADALET_1': 878,
#  'ADAM_1': 670,
#  'ADAM_2': 1924,
#  'ADAY_0': 1515,
#  'ADET_0': 1820,
#  'ADRES _0': 1577,
#  'ADRES _1': 219,
#  'ADRES _2': 1028,
#  'AFERIN _0': 997,
#  'AFFETMEK_0': 109,
#  'AFFETMEK_1': 1314,
#  'AFIŞ_0': 2281,
#  'AIT_0': 940,
#  'AIT_2': 1007,
#  'AKCIĞER_0': 326,
#  'AKICI_0': 1485,
#  'AKICI_1': 683,
#  'AKILLI, ZEKI_0': 934,
#  'AKILSIZ_0': 1119,
#  'AKILSIZ_1': 2395,
#  'AKIL_0': 2053,
#  'AKITMAK _0': 1138,
#  'AKLA GELMEK _0': 1731,
#  'AKLA GELMEK _1': 379,
#  'AKLINA ALMAK_0': 15,
#  'AKMAK_0': 1945,
#  'AKMAK_1': 797,
#  'AKTARMAK_0': 1063,
#  'AKŞAM_0': 2107,
#  'ALAKA_0': 1586,
#  'ALAKA_1': 127,
#  'ALAKA_2': 907,
#  'ALAN_0': 385,
#  'ALAY_0': 368,
#  'ALAY_1': 603,
#  'ALDATMAK_0': 1760,
#  'ALDATMAK_1': 695,
#  'ALERJI_1': 763,
#  'ALERJI_2': 2122,
#  'ALET_0': 999,
#  'ALINMAK_0': 1619,
#  'ALINMAK_1': 1933,
#  'ALIN_0': 2056,
#  'ALIŞMAK_0': 1767,
#  'ALIŞMAK_1': 675,
#  'ALIŞVERIŞ_1': 2423,
#  'ALKIŞ_0': 947,
#  'ALKIŞ_1': 780,
#  'ALKOL, İÇKI_1': 2021,
#  'ALLAH KORUSUN_0': 855,
#  'ALLAHA ŞÜKÜR_0': 2441,
#  'ALLAHA ŞÜKÜR_1': 519,
#  'ALMAK_1': 237,
#  'ALMAN_0': 1671,
#  'ALT _0': 576,
#  'ALTIN_0': 1175,
#  'ALTMIŞ_0': 1657,
#  'ALTMIŞ_1': 1023,
#  'ALTYAZI _0': 2010,
#  'ALTYAZI _1': 664,
#  'ALÇI_0': 785,
#  'ALÇI_1': 843,
#  'AMAN_0': 36,
#  'AMAN_1': 674,
#  'AMA_0': 517,
#  'AMBULANS_0': 419,
#  'AMCA _1': 289,
#  'AMIR_1': 347,
#  'ANADOLU_0': 845,
#  'ANAHTAR_0': 659,
#  'ANAOKULU_0': 800,
#  'ANA_0': 1526,
#  'ANLAM_0': 28,
#  'ANLATMAK_0': 1285,
#  'ANLAŞMAK_0': 3,
#  'ANLAŞMAK_1': 1939,
#  'ANLAŞMA_0': 1590,
#  'ANLAŞMA_1': 2,
#  'ANNEANNE_0': 1444,
#  'ANNE_0': 2473,
#  'ANTLAŞMA_0': 814,
#  'ANTRENMAN_0': 92,
#  'ANTRENÖR_0': 1598,
#  'AN_0': 102,
#  'AN_1': 579,
#  'APANDISIT_0': 1392,
#  'APARTMAN_0': 1839,
#  'APTAL_0': 2065,
#  'APTAL_1': 1781,
#  'ARABA_0': 2402,
#  'ARALIK_0': 708,
#  'ARAMAK _0': 1016,
#  'ARAP_0': 2147,
#  'ARAP_1': 1325,
#  'ARA_0': 372,
#  'ARAŞTIRMAK_0': 1951,
#  'ARAŞTIRMA_0': 284,
#  'ARKADAŞ_0': 414,
#  'ARKA_0': 1601,
#  'ARTIRMAK_1': 2219,
#  'ARTMAK _0': 2151,
#  'ARTMAK _1': 2456,
#  'ARTMAK _2': 539,
#  'ARZU, İSTEK_0': 1455,
#  'ASKER_0': 2016,
#  'ASLAN_0': 55,
#  'ASLA_0': 439,
#  'ASLA_1': 2493,
#  'ASMAK_0': 809,
#  'ASMAK_1': 954,
#  'ATEŞ_0': 21,
#  'ATKI_0': 1739,
#  'ATLAMAK_0': 925,
#  'ATLAMAK_1': 558,
#  'ATMAK_0': 451,
#  'AT_0': 1728,
#  'AUT_0': 1852,
#  'AVANS _0': 1772,
#  'AVANTAJ_0': 1340,
#  'AVANTAJ_1': 1935,
#  'AYAK BASMAK_0': 1313,
#  'AYAKKABI _0': 1538,
#  'AYARLAMAK_0': 170,
#  'AYARLAMAK_1': 1214,
#  'AYARLAMAK_2': 584,
#  'AYIP_0': 1159,
#  'AYIP_1': 1456,
#  'AYIRMAK_2': 1411,
#  'AYLIK_0': 1057,
#  'AYNA_0': 1367,
#  'AYNEN ILETMEK_0': 432,
#  'AYNI_0': 1889,
#  'AYRAN_1': 2096,
#  'AYRILMAK _0': 442,
#  'AYRIMCI_0': 2416,
#  'AZALMAK _0': 1979,
#  'AZALMAK _1': 37,
#  'AZALTMAK_0': 680,
#  'AZIM_0': 1989,
#  'AZ_0': 1473,
#  'AÇGÖZLÜ_0': 1943,
#  'AÇIKLAMAK_0': 491,
#  'AÇIK_0': 1040,
#  'AÇIK_1': 2485,
#  'AÇIK_2': 807,
#  'AÇILMAK_0': 1230,
#  'AÇMAK_0': 2200,
#  'AÇMAK_2': 1970,
#  'AÇ_0': 2341,
#  'AĞAÇ _0': 2368,
#  'AĞAÇ _1': 1050,
#  'AĞIR_0': 195,
#  'AĞIZ_0': 948,
#  'AĞLAMAK_0': 2254,
#  'AĞLAMAK_1': 1137,
#  'AĞRIMAK_0': 215,
#  'AĞRIMAK_1': 369,
#  'AĞRIMAK_2': 806,
#  'AĞRITMAK_0': 2379,
#  'AĞRITMAK_2': 1446,
#  'AĞRI_0': 502,
#  'AĞZI AÇIK KALMAK_0': 2487,
#  'AŞAĞILAMAK_0': 234,
#  'AŞAĞILAMAK_1': 636,
#  'AŞAĞI_0': 1098,
#  'AŞAĞI_1': 373,
#  'AŞIK OLMAK_1': 530,
#  'AŞI_0': 2211,
#  'BABAANNE_0': 747,
#  'BABA_0': 355,
#  'BACAK_0': 1251,
#  'BADANA_0': 1571,
#  'BAHÇE_0': 101,
#  'BAHÇE_1': 1292,
#  'BAHŞIŞ_1': 1782,
#  'BAHŞIŞ_2': 1521,
#  'BAKIM_0': 2189,
#  'BAKIM_1': 2274,
#  'BAKIŞMAK_0': 196,
#  'BAKIŞMA_0': 1759,
#  'BAKIŞMA_1': 2437,
#  'BAKIŞ_0': 210,
#  'BAKKAL _0': 1348,
#  'BAKKAL _1': 1302,
#  'BAKKAL _2': 89,
#  'BAKMAK_0': 1490,
#  'BAKMAK_1': 2399,
#  'BAKMAK_2': 1124,
#  'BALIK_0': 280,
#  'BALIK_1': 444,
#  'BALKON_0': 1207,
#  'BALKON_1': 723,
#  'BALKON_2': 689,
#  'BALON_0': 2060,
#  'BALTALAMAK_1': 354,
#  'BALTA_0': 1100,
#  'BAL_0': 909,
#  'BANKA_0': 1036,
#  'BANK_0': 776,
#  'BANTLAMAK_0': 1644,
#  'BANYO_0': 1081,
#  'BARDAK _0': 2428,
#  'BARDAK _1': 592,
#  'BARDAK _2': 2417,
#  'BARIŞMAK _1': 1022,
#  'BARIŞMAK _2': 1351,
#  'BARIŞ_0': 830,
#  'BARIŞ_1': 370,
#  'BAR_0': 1283,
#  'BAR_1': 174,
#  'BASIT_0': 564,
#  'BASIT_1': 2457,
#  'BASIT_2': 2167,
#  'BASKETBOL_0': 474,
#  'BASMAK _0': 1188,
#  'BATI_1': 1831,
#  'BATMAK_0': 1963,
#  'BATMAK_1': 161,
#  'BAVUL_0': 968,
#  'BAYAT_0': 201,
#  'BAYAT_1': 2398,
#  'BAYILMAK _0': 1239,
#  'BAYILMAK _1': 1681,
#  'BAYRAK_0': 270,
#  'BAYRAM_0': 1229,
#  'BAYRAM_2': 2282,
#  'BAZEN_0': 588,
#  'BAZEN_1': 1513,
#  'BAZEN_2': 1457,
#  'BAĞIMSIZ _0': 278,
#  'BAĞIMSIZ _1': 1546,
#  'BAĞIRMAK _0': 1863,
#  'BAĞIRMAK _1': 1101,
#  'BAĞIRMAK _2': 2435,
#  'BAĞLAMAK _0': 424,
#  'BAĞLAMAK _1': 1146,
#  'BAĞLANMAK_0': 1848,
#  'BAĞLANMAK_2': 357,
#  'BAĞLI_0': 2249,
#  'BAŞ BAŞA_0': 1082,
#  'BAŞ ÜSTÜNE_0': 1816,
#  'BAŞARILI_0': 1122,
#  'BAŞARILI_1': 1718,
#  'BAŞARILI_2': 1361,
#  'BAŞARISIZ_0': 772,
#  'BAŞARISIZ_1': 609,
#  'BAŞARISIZ_2': 165,
#  'BAŞARI_0': 1289,
#  'BAŞARI_1': 507,
#  'BAŞARI_2': 1249,
#  'BAŞARMAK_0': 387,
#  'BAŞARMAK_1': 598,
#  'BAŞBAKAN_0': 974,
#  'BAŞBAKAN_1': 1422,
#  'BAŞI DÖNMEK_0': 254,
#  'BAŞKA_0': 984,
#  'BAŞKA_1': 1639,
#  'BAŞLAMAK_0': 2121,
#  'BAŞPARMAK_2': 2062,
#  'BAŞVURMAK_0': 1006,
#  'BAŞVURU, MÜRACAAT_0': 865,
#  'BAŞ_0': 2264,
#  'BEBEK_0': 2306,
#  'BEDAVA_0': 544,
#  'BEDEN_0': 298,
#  'BEKAR_0': 309,
#  'BEKLEMEK_0': 725,
#  'BELGESEL_0': 514,
#  'BELGE_0': 1755,
#  'BELGE_1': 1070,
#  'BELKI_0': 290,
#  'BELKI_1': 1876,
#  'BELLI_0': 559,
#  'BEMBEYAZ_0': 2176,
#  'BENCE_0': 5,
#  'BENCIL_0': 1143,
#  'BENIM_0': 633,
#  'BENIM_1': 1005,
#  'BENZEMEK _0': 383,
#  'BENZEMEK _1': 1665,
#  'BENZEMEK _2': 1462,
#  'BENZETMEK_0': 194,
#  'BENZETMEK_1': 1189,
#  'BENZETMEK_2': 1202,
#  'BENZIN_0': 1964,
#  'BENZIN_1': 1664,
#  'BEN_0': 1145,
#  'BEN_2': 1966,
#  'BERABER_1': 1495,
#  'BERBAT_0': 727,
#  'BESBELLI_0': 348,
#  'BEYAZ_0': 1906,
#  'BEYAZ_1': 779,
#  'BEYIN_0': 1576,
#  'BEYIN_1': 1431,
#  'BEĞENMEK_0': 1780,
#  'BEŞ VAKIT_0': 1844,
#  'BEŞINCI_0': 345,
#  'BEŞ_0': 884,
#  'BIBER_0': 2197,
#  'BIBER_1': 1742,
#  'BIKMAK_0': 992,
#  'BIKMAK_2': 1501,
#  'BILARDO_0': 2228,
#  'BILEME_0': 1734,
#  'BILET_0': 799,
#  'BILEZIK_0': 2142,
#  'BILGI VERMEK_0': 1549,
#  'BILGISAYAR_0': 971,
#  'BILGI_0': 1220,
#  'BILMEK_0': 911,
#  'BINMEK_1': 2481,
#  'BIN_0': 2120,
#  'BIR DAHA_0': 789,
#  'BIRAKMAK _0': 979,
#  'BIRAKMAK _2': 2490,
#  'BIRAZ_0': 1612,
#  'BIRA_0': 1157,
#  'BIRBIRI_0': 1486,
#  'BIRDEN_0': 1539,
#  'BIRIKTIRMEK_0': 2217,
#  'BIRIKTIRMEK_1': 2223,
#  'BIRI_0': 1817,
#  'BIRKAÇ_0': 892,
#  'BIRLEŞMEK_0': 641,
#  'BIRLEŞMEK_2': 1394,
#  'BIRLIK _1': 2376,
#  'BIRLIK _2': 2270,
#  'BIRLIKTE_0': 593,
#  'BIR_0': 137,
#  'BIRŞEY_0': 2124,
#  'BIRŞEY_1': 898,
#  'BISIKLET_0': 1931,
#  'BITIRMEK_1': 1694,
#  'BITMEK _1': 2295,
#  'BITMEK _2': 1589,
#  'BIYIK_0': 1364,
#  'BIÇAKLAMAK_0': 1102,
#  'BIÇAK_0': 2043,
#  'BLUZ_0': 988,
#  'BLUZ_1': 1103,
#  'BOL_0': 698,
#  'BOL_2': 1215,
#  'BOMBALAMAK_0': 945,
#  'BOMBALAMAK_1': 2204,
#  'BORU_1': 589,
#  'BOT_0': 899,
#  'BOYAMAK_0': 1156,
#  'BOYAMAK_1': 343,
#  'BOYAMAK_2': 2445,
#  'BOYA_0': 2188,
#  'BOYUN_1': 1738,
#  'BOY_0': 2336,
#  'BOZUK_0': 1021,
#  'BOZULMAK _0': 827,
#  'BOĞAZ_0': 841,
#  'BOĞA_0': 1932,
#  'BOĞULMAK_0': 521,
#  'BOĞULMAK_1': 50,
#  'BOĞULMAK_2': 1254,
#  'BOŞ OTURMAK_0': 2103,
#  'BOŞ VERMEK_0': 10,
#  'BOŞ VERMEK_1': 307,
#  'BOŞANMAK _0': 942,
#  'BOŞ_0': 337,
#  'BOŞ_1': 2286,
#  'BOŞ_2': 465,
#  'BRAVO_0': 2128,
#  'BRAVO_1': 2230,
#  'BRAVO_2': 682,
#  'BROŞÜR_1': 1996,
#  'BU KADAR_0': 628,
#  'BU KADAR_1': 2076,
#  'BUGÜN_0': 1218,
#  'BUGÜN_1': 333,
#  'BUHAR_0': 1267,
#  'BULANIK_0': 1093,
#  'BULANMAK_0': 1479,
#  'BULANMAK_1': 1370,
#  'BULANTI_0': 1278,
#  'BULAŞIK_0': 1978,
#  'BULAŞIK_2': 1227,
#  'BULAŞMAK_0': 1316,
#  'BULGUR_1': 420,
#  'BULUT_1': 401,
#  'BULUŞMAK_0': 1222,
#  'BUNALMAK_0': 1709,
#  'BURA_0': 41,
#  'BURA_1': 849,
#  'BURA_2': 1105,
#  'BURNUNU SOKMAK_0': 2405,
#  'BURUN_0': 1053,
#  'BURUN_1': 1337,
#  'BU_0': 238,
#  'BÖBREK_1': 46,
#  'BÖLGE _0': 2262,
#  'BÖLMEK_0': 353,
#  'BÖLME_0': 1940,
#  'BÖLÜM_0': 2098,
#  'BÖREK _1': 78,
#  'BÖYLE _0': 1318,
#  'BÖYLE _2': 1814,
#  'BÜTÜN_0': 2059,
#  'BÜTÜN_1': 1500,
#  'BÜTÜN_2': 2111,
#  'BÜYÜK_0': 1983,
#  'BÜYÜK_1': 332,
#  'BÜYÜKŞEHIR_0': 2048,
#  'BÜYÜKŞEHIR_1': 247,
#  'BÜYÜMEK_0': 1916,
#  'BÜYÜMEK_1': 919,
#  'BÜYÜME_0': 1120,
#  'BÜYÜME_1': 1556,
#  'BÜYÜME_2': 1595,
#  'BÜYÜTMEK _2': 2353,
#  'BÜYÜ_0': 2069,
#  'BÜYÜ_1': 1317,
#  'CAHIL _0': 518,
#  'CAMI_0': 1253,
#  'CAMI_1': 1180,
#  'CAM_0': 503,
#  'CAM_1': 1275,
#  'CANAVAR_0': 2343,
#  'CANI ACIMAK_0': 1311,
#  'CANI ACIMAK_1': 1088,
#  'CANI ÇEKMEK _0': 487,
#  'CANLI_1': 2407,
#  'CAN_0': 85,
#  'CD_0': 388,
#  'CENNET_0': 2425,
#  'CEP TELEFONU_0': 1390,
#  'CEP TELEFONU_1': 1928,
#  'CEP_0': 2261,
#  'CEP_1': 1840,
#  'CESARET_0': 1334,
#  'CESARET_1': 1064,
#  'CESUR_0': 1508,
#  'CEVAP VERMEK, CEVAPLAMAK_0': 2165,
#  'CEVAP_0': 1287,
#  'CEZA KESMEK, CEZA VERMEK_0': 93,
#  'CEZA_0': 2136,
#  'CIDDI_0': 1790,
#  'CIMRI_0': 617,
#  'CIPS_0': 29,
#  'CIĞER _0': 425,
#  'COĞRAFYA_0': 2029,
#  'CUMARTESI_0': 2388,
#  'CUMARTESI_1': 389,
#  'CUMHURBAŞKANI_1': 1959,
#  'CUMHURBAŞKANI_2': 458,
#  'CUMHURIYET_0': 418,
#  'CUMHURIYET_1': 2401,
#  'CÜMLE, TÜMCE_0': 90,
#  'DAHA_0': 2215,
#  'DAIRE_0': 1984,
#  'DAIRE_1': 1056,
#  'DAKTILO_2': 1894,
#  'DALGA GEÇMEK_0': 2363,
#  'DALGA_0': 2227,
#  'DALIŞ_0': 1127,
#  'DAMAR_0': 251,
#  'DAMLA_0': 2184,
#  'DANIŞMAN_1': 1842,
#  'DANS ETMEK_0': 1726,
#  'DANS _1': 322,
#  'DAR_0': 260,
#  'DAVA_0': 1221,
#  'DAVET ETMEK_0': 1305,
#  'DAVET _1': 407,
#  'DAVET _2': 1867,
#  'DAVUL_0': 253,
#  'DAYANMAK _0': 1354,
#  'DAYANMAK _1': 1170,
#  'DAYI_0': 1828,
#  'DAĞ_1': 158,
#  'DELEGE_0': 2244,
#  'DELI_0': 160,
#  'DEMIR_0': 2199,
#  'DEMOKRASI_0': 2397,
#  'DENEME _0': 2491,
#  'DENEMEK_0': 1893,
#  'DENIZ_0': 1534,
#  'DERECE _0': 2426,
#  'DERE_0': 1615,
#  'DERGI_0': 416,
#  'DERIN_0': 987,
#  'DERIN_1': 472,
#  'DERIN_2': 1776,
#  'DERI_0': 2109,
#  'DERI_1': 1807,
#  'DERI_2': 1913,
#  'DERNEK_0': 608,
#  'DERS _1': 1012,
#  'DERS ÇALIŞMAK_0': 2495,
#  'DESTEKLEMEK_0': 1320,
#  'DEV _0': 98,
#  'DEV _1': 1478,
#  'DEVAM ETMEK_0': 1183,
#  'DEVAM ETMEK_2': 1373,
#  'DEVAMLI_1': 2335,
#  'DEVAMSIZ_0': 2192,
#  'DEVLET_0': 2039,
#  'DEVRALMAK_1': 960,
#  'DEVRILMEK_1': 1858,
#  'DEVRILMEK_2': 2024,
#  'DEĞER_0': 1393,
#  'DEĞIL_0': 1691,
#  'DEĞIRMEN_1': 1518,
#  'DEĞIŞ TOKUŞ_0': 49,
#  'DEĞIŞ TOKUŞ_1': 1192,
#  'DEĞIŞIK _0': 147,
#  'DEĞIŞIK _2': 852,
#  'DEĞIŞMEK_0': 2077,
#  'DEĞIŞMEK_1': 2041,
#  'DEĞIŞTIRMEK_0': 1561,
#  'DEĞIŞTIRMEK_1': 844,
#  'DEĞIŞTIRMEK_2': 1339,
#  'DIKDÖRTGEN_0': 1583,
#  'DIKILMEK_0': 494,
#  'DIKILMEK_1': 1622,
#  'DIKIŞ DIKMEK_0': 1736,
#  'DIKIŞ DIKMEK_1': 1668,
#  'DIKIŞ_1': 67,
#  'DIKKAT ETMEK_0': 2446,
#  'DIKKAT ETMEK_1': 1869,
#  'DIKKAT_1': 1307,
#  'DIKMEK_0': 162,
#  'DIKMEK_1': 56,
#  'DIKMEK_2': 1569,
#  'DILEKÇE _0': 1654,
#  'DILEKÇE _2': 2297,
#  'DILEMEK_0': 431,
#  'DIL_0': 2381,
#  'DINCI_0': 1328,
#  'DINLEMEK_0': 2186,
#  'DINLENMEK_0': 928,
#  'DIN_0': 1866,
#  'DIN_1': 1288,
#  'DIN_2': 864,
#  'DIPLOMA _1': 717,
#  'DIPLOMA _2': 2421,
#  'DIREKT, DOĞRUDAN_0': 122,
#  'DISKO_0': 875,
#  'DISKO_1': 2240,
#  'DIZ _0': 1000,
#  'DIZ _1': 1953,
#  'DIZI _0': 18,
#  'DIZÜSTÜ BILGISAYAR, LAPTOP_0': 1621,
#  'DIZÜSTÜ BILGISAYAR, LAPTOP_1': 485,
#  'DIĞER_1': 269,
#  'DIŞARI _0': 1111,
#  'DIŞARI _1': 2004,
#  'DIŞ_0': 1547,
#  'DOKTOR_0': 714,
#  'DOKUNMAK_0': 2173,
#  'DOKUNMATIK_0': 1557,
#  'DOKUZ_0': 1662,
#  'DOLANDIRMAK_0': 2287,
#  'DOLAP_0': 464,
#  'DOLAP_1': 1768,
#  'DOLDURMAK_0': 351,
#  'DOLDURMAK_1': 1196,
#  'DOLMAK_0': 4,
#  'DOLMUŞ_0': 1947,
#  'DOLMUŞ_1': 2469,
#  'DOLMUŞ_2': 1716,
#  'DOMATES_0': 156,
#  'DONDURMA_0': 1164,
#  'DONDURMA_1': 1065,
#  'DOST _0': 2185,
#  'DOSYA_0': 2366,
#  'DOYMAK_0': 231,
#  'DOYMAK_1': 81,
#  'DOĞAL _0': 62,
#  'DOĞALGAZ_0': 2190,
#  'DOĞALGAZ_1': 1191,
#  'DOĞMAK_0': 456,
#  'DOĞRU_0': 1004,
#  'DOĞUM_0': 1297,
#  'DOĞUM_1': 704,
#  'DOĞU_0': 206,
#  'DUA_0': 528,
#  'DUDAK_1': 2191,
#  'DUMAN_0': 2290,
#  'DURAK_0': 2410,
#  'DURDURMAK_0': 35,
#  'DURMAK_0': 1982,
#  'DUYGULANMAK _1': 792,
#  'DUYMAK_0': 128,
#  'DÖKMEK_1': 757,
#  'DÖNER_0': 1266,
#  'DÖNER_1': 1381,
#  'DÖNMEK_1': 1740,
#  'DÖNMEK_2': 953,
#  'DÖNÜŞTÜRMEK_0': 741,
#  'DÖNÜŞTÜRMEK_1': 2232,
#  'DÖNÜŞ_0': 2429,
#  'DÖNÜŞ_1': 950,
#  'DÖVMEK_0': 193,
#  'DÜKKAN_0': 459,
#  'DÜNYA_0': 1182,
#  'DÜNYA_1': 113,
#  'DÜNYA_2': 449,
#  'DÜN_0': 854,
#  'DÜN_1': 469,
#  'DÜZELMEK_0': 1181,
#  'DÜZELTMEK_0': 184,
#  'DÜZENLEMEK_0': 755,
#  'DÜZENLEMEK_1': 115,
#  'DÜZ_0': 2271,
#  'DÜZ_1': 1206,
#  'DÜĞME_0': 644,
#  'DÜĞME_1': 100,
#  'DÜĞME_2': 957,
#  'DÜĞÜN_0': 504,
#  'DÜŞMAN_0': 1384,
#  'DÜŞMEK_0': 2135,
#  'DÜŞMEK_1': 835,
#  'DÜŞÜK_0': 596,
#  'DÜŞÜK_1': 1683,
#  'DÜŞÜK_2': 1542,
#  'DÜŞÜNCE, FIKIR_1': 824,
#  'DÜŞÜNCE, FIKIR_2': 546,
#  'DÜŞÜNMEK_1': 1661,
#  'EBE_0': 1336,
#  'EBE_1': 1326,
#  'EFENDI_0': 1436,
#  'EFENDI_1': 562,
#  'EHLIYET_0': 922,
#  'EKIM_0': 323,
#  'EKIM_1': 8,
#  'EKIM_2': 2354,
#  'EKMEK_0': 1554,
#  'EKMEK_1': 1019,
#  'EKONOMIK_0': 795,
#  'EKONOMIK_1': 1593,
#  'EKONOMI_0': 1018,
#  'EKONOMI_1': 1919,
#  'EKONOMI_2': 1074,
#  'EKRAN_0': 495,
#  'EKRAN_1': 2025,
#  'EKSIK_2': 180,
#  'EKSI_0': 1366,
#  'EL SALLAMAK_0': 12,
#  'EL SALLAMAK_1': 1826,
#  'EL SIKMAK_0': 1404,
#  'EL SIKMAK_1': 2208,
#  'EL ÖPMEK_0': 1722,
#  'EL ÖPMEK_1': 1243,
#  'EL ÖPMEK_2': 2470,
#  'ELBISE _0': 1279,
#  'ELDIVEN_0': 457,
#  'ELEKTRIK_0': 668,
#  'ELEKTRONIK POSTA, E-POSTA_0': 2073,
#  'ELEKTRONIK_0': 832,
#  'ELEMEK_1': 1414,
#  'ELHAMDÜLILLAH_0': 2256,
#  'ELHAMDÜLILLAH_1': 1426,
#  'ELHAMDÜLILLAH_2': 2237,
#  'ELLEMEK_0': 927,
#  'ELLI (50)_0': 1642,
#  'ELLI (50)_1': 1525,
#  'ELMA_1': 1548,
#  'EL_0': 1484,
#  'EL_1': 1273,
#  'EMEKLI _0': 1877,
#  'EMEK_1': 498,
#  'EMEK_2': 1032,
#  'EMIN_0': 2138,
#  'EMIN_1': 972,
#  'EMIR_0': 277,
#  'EMNIYET _0': 148,
#  'EMNIYET _2': 168,
#  'EMRETMEK, EMIR VERMEK_0': 1397,
#  'EMZIK_0': 2258,
#  'EMZIK_1': 1300,
#  'EMZIK_2': 2257,
#  'EMZIRMEK_0': 202,
#  'EMZIRMEK_1': 2210,
#  'EMZIRMEK_2': 926,
#  'ENAYI_0': 1089,
#  'ENDIŞELI_0': 522,
#  'ENDIŞELI_1': 1973,
#  'ENGELLEMEK_0': 1634,
#  'ENGELLEMEK_2': 2008,
#  'ENGELLI_0': 758,
#  'ENGEL_1': 256,
#  'ENGEL_2': 216,
#  'ERIK _0': 366,
#  'ERIK _1': 1584,
#  'ERIŞTE_0': 896,
#  'ERKEK_0': 1872,
#  'ERKEK_1': 1341,
#  'ERKEN_0': 2164,
#  'ERTELENMEK_0': 77,
#  'ESKI_0': 618,
#  'ESKI_1': 1805,
#  'ESPRI_0': 1136,
#  'ESPRI_1': 2119,
#  'ETEK_0': 342,
#  'ETEK_1': 1080,
#  'ETRAF_0': 1941,
#  'ET_0': 395,
#  'EVET_0': 2180,
#  'EVET_1': 344,
#  'EVLENMEK_0': 39,
#  'EVLILIK_0': 313,
#  'EVLI_0': 103,
#  'EVRAK_0': 583,
#  'EV_0': 1997,
#  'EYLÜL_0': 1968,
#  'EYLÜL_1': 1003,
#  'EYLÜL_2': 191,
#  'EZBERLEMEK_1': 2166,
#  'EZBER_0': 423,
#  'EZILMEK_0': 2035,
#  'EZILMEK_1': 79,
#  'EZILMEK_2': 1442,
#  'EZIYET_0': 2099,
#  'EZIYET_2': 1033,
#  'EZMEK_2': 969,
#  'EĞER_0': 59,
#  'EĞER_1': 1560,
#  'EĞITIM_0': 709,
#  'EĞITMEK_0': 671,
#  'EĞLENCE_0': 1818,
#  'EĞLENMEK_0': 1992,
#  'EĞMEK_0': 143,
#  'EĞMEK_1': 833,
#  'EĞMEK_2': 2012,
#  'EŞIT _1': 2028,
#  'EŞIT _2': 2202,
#  'EŞOFMAN_1': 1827,
#  'EŞYA_0': 441,
#  'EŞ_0': 1115,
#  'FAKIR_0': 1737,
#  'FARE, MOUSE_0': 810,
#  'FARE_0': 765,
#  'FARE_1': 2233,
#  'FARK ETMEZ_0': 1733,
#  'FARK ETMEZ_1': 679,
#  'FARKETMEK_0': 169,
#  'FARKLI_0': 2377,
#  'FARK_0': 894,
#  'FATURA_0': 1374,
#  'FAVORI_0': 883,
#  'FAYDA_0': 1388,
#  'FAZLA_1': 2383,
#  'FAZLA_2': 970,
#  'FEDERASYON_0': 1629,
#  'FELÇ_0': 340,
#  'FENA_0': 1779,
#  'FERAHLAMAK_0': 43,
#  'FILM_1': 527,
#  'FINAL_0': 513,
#  'FIRIN _1': 1530,
#  'FIRLAMAK_0': 1725,
#  'FIRMA_0': 1344,
#  'FIRMA_1': 1972,
#  'FIRÇA_0': 1801,
#  'FIRÇA_1': 427,
#  'FIRÇA_2': 1445,
#  'FITNESS_0': 1187,
#  'FIŞ_0': 1353,
#  'FLÖRT_0': 2332,
#  'FLÖRT_1': 2006,
#  'FLÜT_0': 452,
#  'FOTOKOPI_0': 1645,
#  'FOTOKOPI_1': 1813,
#  'FOTOĞRAF ÇEKMEK_0': 2449,
#  'FOTOĞRAF_0': 380,
#  'FREN_0': 2450,
#  'FREN_1': 1802,
#  'FUAR_0': 1363,
#  'FUTBOL_1': 943,
#  'GALIBA_1': 1786,
#  'GARANTI_0': 1217,
#  'GASP ETMEK_0': 834,
#  'GAVUR_0': 1911,
#  'GECE_0': 1197,
#  'GECIKMEK_0': 808,
#  'GELECEK_0': 2049,
#  'GELECEK_1': 694,
#  'GELENEKSEL_0': 118,
#  'GELENEK_0': 1667,
#  'GELIN_0': 921,
#  'GELIN_1': 460,
#  'GELIN_2': 2430,
#  'GELIŞMEK _0': 390,
#  'GELIŞMEK _1': 775,
#  'GELIŞMEK _2': 2030,
#  'GELIŞTIRMEK _0': 724,
#  'GELIŞTIRMEK _1': 2000,
#  'GELMEK_0': 1332,
#  'GELMEK_1': 1823,
#  'GEMI_0': 1177,
#  'GENEL_0': 1934,
#  'GENEL_1': 1811,
#  'GENETIK_0': 1727,
#  'GENIŞ_0': 1377,
#  'GENÇ_0': 461,
#  'GEOMETRI_0': 831,
#  'GEREK _0': 2444,
#  'GEREK _1': 1415,
#  'GEREK _2': 1887,
#  'GEREKMEK_0': 684,
#  'GEREKMEK_1': 2488,
#  'GEREKMEK_2': 104,
#  'GERI_0': 2406,
#  'GERÇEK_0': 1154,
#  'GERÇEK_1': 2020,
#  'GEVEZE _0': 185,
#  'GEVEZE _1': 435,
#  'GEZDIRMEK_0': 1470,
#  'GEZDIRMEK_1': 1752,
#  'GEZMEK_0': 678,
#  'GEÇIT_0': 998,
#  'GEÇMEK_1': 2222,
#  'GEÇMEK_2': 1474,
#  'GEÇMIŞ OLSUN_0': 1699,
#  'GEÇMIŞ OLSUN_2': 34,
#  'GEÇMIŞ_0': 1246,
#  'GEÇMIŞ_1': 2497,
#  'GEÇMIŞ_2': 179,
#  'GEÇ_0': 66,
#  'GIBI_1': 1224,
#  'GIDIŞ DÖNÜŞ_0': 2302,
#  'GIDIŞ DÖNÜŞ_1': 1179,
#  'GIDIŞ DÖNÜŞ_2': 358,
#  'GIRIŞ_0': 1075,
#  'GIRIŞ_1': 220,
#  'GIRMEK_1': 154,
#  'GITAR_0': 1623,
#  'GITMEK_0': 781,
#  'GITMEK_2': 1856,
#  'GIYIM_1': 542,
#  'GIYMEK_1': 1938,
#  'GIYSI_0': 577,
#  'GIYSI_1': 2177,
#  'GIZLI_2': 666,
#  'GOL_0': 1822,
#  'GOL_1': 350,
#  'GRAFIK_1': 163,
#  'GRAM_0': 1268,
#  'GRUP_0': 1480,
#  'GURURLANMAK_1': 1250,
#  'GÖNDERMEK, YOLLAMAK_0': 1001,
#  'GÖREV_0': 607,
#  'GÖREV_1': 1995,
#  'GÖRE_0': 981,
#  'GÖRMEK_1': 304,
#  'GÖRMEK_2': 38,
#  'GÖRÜNTÜLÜ (GÖRÜŞME)_0': 1993,
#  'GÖRÜNTÜ_0': 490,
#  'GÖRÜŞMEK_1': 590,
#  'GÖSTERMEK_0': 1969,
#  'GÖSTERMEK_2': 362,
#  'GÖTÜRMEK_0': 224,
#  'GÖTÜRMEK_1': 1808,
#  'GÖTÜRMEK_2': 166,
#  'GÖVDE_0': 1686,
#  'GÖVDE_1': 2081,
#  'GÖVDE_2': 2278,
#  'GÖZLÜK_0': 381,
#  'GÖÇMEN_0': 890,
#  'GÖÇMEN_1': 483,
#  'GÖĞÜS, MEME_0': 2327,
#  'GÖĞÜS, MEME_1': 135,
#  'GÖĞÜS, MEME_2': 1405,
#  'GÜLDÜRMEK_0': 889,
#  'GÜLDÜRMEK_2': 2326,
#  'GÜLMEK, KAHKAHA ATMAK_1': 2170,
#  'GÜLMEK, KAHKAHA ATMAK_2': 2246,
#  'GÜL_0': 620,
#  'GÜLÜMSEMEK_0': 141,
#  'GÜMÜŞ _0': 2356,
#  'GÜNAH_0': 663,
#  'GÜNEŞ_0': 1076,
#  'GÜNLÜK_0': 172,
#  'GÜN_0': 2351,
#  'GÜN_1': 873,
#  'GÜREŞ_0': 1335,
#  'GÜRÜLTÜ_0': 2312,
#  'GÜVENLIK_0': 2070,
#  'GÜVENLIK_1': 151,
#  'GÜVENMEK_0': 82,
#  'GÜVEN_0': 716,
#  'GÜZEL_1': 532,
#  'GÜZEL_2': 573,
#  'GÜÇ _0': 329,
#  'GÜÇ _1': 1255,
#  'GÜÇ _2': 1596,
#  'GÜÇLÜ _1': 1988,
#  'GÜÇLÜ _2': 1234,
#  'HABER VERMEK_0': 406,
#  'HABER _0': 793,
#  'HABER _1': 1581,
#  'HABERLEŞMEK_0': 541,
#  'HACI_0': 1956,
#  'HAFIF_0': 155,
#  'HAFIZA_0': 281,
#  'HAFTA_0': 2161,
#  'HAKIM_0': 31,
#  'HAKIM_1': 341,
#  'HAKLI_0': 1875,
#  'HAK_0': 2384,
#  'HALK_0': 1029,
#  'HAMAM_0': 1682,
#  'HAMBURGER_0': 314,
#  'HAMILE_0': 86,
#  'HAMILE_1': 1092,
#  'HAMUR _0': 1235,
#  'HAMUR _1': 805,
#  'HANGI_0': 375,
#  'HANGI_2': 515,
#  'HARAM_0': 60,
#  'HARCAMAK_0': 2220,
#  'HAREKET_0': 1223,
#  'HAREKET_2': 2339,
#  'HARIKA_0': 929,
#  'HARIKA_1': 1613,
#  'HARIKA_2': 1060,
#  'HASTANE_0': 786,
#  'HASTA_1': 1132,
#  'HASTA_2': 233,
#  'HATA _0': 669,
#  'HATA _1': 1962,
#  'HATIRA _1': 1920,
#  'HATIRLAMAK_0': 1163,
#  'HAVA ATMAK_1': 2275,
#  'HAVALI_0': 1209,
#  'HAVALI_1': 599,
#  'HAVALI_2': 1713,
#  'HAVA_0': 339,
#  'HAVA_1': 274,
#  'HAVUZ_0': 2071,
#  'HAVUZ_1': 783,
#  'HAYAL ETMEK_0': 2252,
#  'HAYAL_1': 1579,
#  'HAYAT _0': 639,
#  'HAYAT _1': 1904,
#  'HAYDI_0': 2141,
#  'HAYIR _0': 2084,
#  'HAYIRLI OLSUN_0': 1821,
#  'HAYIRLI OLSUN_1': 1071,
#  'HAYRAN KALMAK_0': 766,
#  'HAYRAN KALMAK_1': 731,
#  'HAYRAN_0': 705,
#  'HAYRAN_1': 226,
#  'HAYVAN_0': 826,
#  'HAYVAN_1': 1585,
#  'HAZIRAN_0': 208,
#  'HAZIRAN_1': 910,
#  'HAZIRLIK_0': 1785,
#  'HAZIRLIK_1': 2436,
#  'HAZIRLIK_2': 2424,
#  'HEDEF_0': 2476,
#  'HEDEF_1': 2374,
#  'HEDIYE VERMEK, HEDIYE ETMEK_0': 2093,
#  'HEDIYE_0': 707,
#  'HELIKOPTER_0': 2279,
#  'HEMEN_1': 1918,
#  'HEMEN_2': 2349,
#  'HEM_0': 648,
#  'HEMŞIRE _0': 1597,
#  'HEMŞIRE _1': 1757,
#  'HEPSI_0': 2057,
#  'HEPSI_2': 1155,
#  'HER _0': 1349,
#  'HER _1': 804,
#  'HER _2': 958,
#  'HERKES_0': 821,
#  'HERŞEY _1': 1744,
#  'HESAP MAKINESI_1': 1845,
#  'HESAP _0': 421,
#  'HESAP _2': 266,
#  'HESAPLAMAK_0': 508,
#  'HESAPLAMAK_1': 1212,
#  'HESAPLAMAK_2': 568,
#  'HEVES_0': 142,
#  'HEYECAN_1': 2106,
#  ...}

# %%
from fastdtw import fastdtw
from scipy.spatial.distance import euclidean

SIMILARITY = {}

IDX = 1225

zip_lex = list(zip(CLS.LEXICON,CLS.VECTORS))

for word, candidate in tqdm(zip_lex):

    KEYS = list(KEY_SET.intersection(set(list(candidate.keys())).intersection(CLS.VECTORS[IDX].keys())))
    
    # v0
    BASE = CLS.VECTORS[IDX]
    sim = 0
    kk = 0
    for dim in KEYS:
        #sim += dtw(BASE[dim], candidate[dim])
        try:
            v1, v2 = np.array([BASE[dim].to_list()]), np.array([candidate[dim].to_list()])
            min_len = min([v1.shape[1],v2.shape[1]])
            
            pad = math.floor(abs(v1.shape[1]-v2.shape[1]) / 2)
            
            sim += fastdtw(v1[:,:min_len], v2[:,:min_len], dist=euclidean)[0]
            kk += 1
        except:
            pass


    if kk: SIMILARITY[word] = sim / kk
    
print(CLS.LEXICON[IDX])
vla = pd.DataFrame(sorted(SIMILARITY.items(), key=lambda x:x[1], reverse=False))

return vla
# Out:
# 100%|██████████| 2500/2500 [00:02<00:00, 1123.63it/s]
# AD, İSIM_0
#   File "/var/folders/3n/htgy5xms739d5j9z9r7lw1540000gn/T/ipykernel_13376/2132087593.py", line 37
#     return vla
#     ^
# SyntaxError: 'return' outside function

# %%
print(CLS.LEXICON[IDX])
vla = pd.DataFrame(sorted(SIMILARITY.items(), key=lambda x:x[1], reverse=False))
vla.head(50)
# Out:
# AD, İSIM_0
#                     0          1
# 0          AD, İSIM_0   0.000000
# 1              BLUZ_1  30.104860
# 2             ERKEK_1  33.907835
# 3            SAĞLAM_1  37.196351
# 4          ANAOKULU_0  39.698024
# 5          KORKMAK _0  39.821674
# 6          TITREMEK_1  40.133052
# 7          KAZANMAK_1  40.292848
# 8           ALINMAK_1  41.128421
# 9              SARI_1  43.411510
# 10             KAFA_0  46.203166
# 11           MITING_0  46.298805
# 12           GÜÇLÜ _2  46.383405
# 13         KIRILMAK_0  46.614348
# 14              CEP_0  46.738106
# 15            SEVAP_0  46.793420
# 16           YUMRUK_0  46.848113
# 17        ORTAOKUL _1  47.084794
# 18       ONAYLANMAK_0  47.405733
# 19             LOGO_1  47.484361
# 20           BILMEK_0  47.587654
# 21            KOKU _2  47.857784
# 22       PROPAGANDA_0  47.952428
# 23            ŞUBAT_2  48.336830
# 24            ALMAN_0  48.444487
# 25          SEMINER_0  48.499339
# 26          KABAHAT_0  48.537592
# 27            KORKU_0  48.819322
# 28           SILMEK_1  48.846965
# 29  UZAKTAN KUMANDA_0  48.879529
# 30           ÇOCUK _0  48.968275
# 31       BIÇAKLAMAK_0  49.247740
# 32           ÜCRET _2  49.399722
# 33            ÇAMUR_0  49.421350
# 34             AYIP_1  49.530639
# 35            YEDEK_0  49.540837
# 36            TORBA_0  49.556343
# 37            PEŞIN_0  49.624113
# 38          SIKINTI_1  49.810560
# 39            YEDEK_1  49.830444
# 40          HATIRA _1  50.006496
# 41              YAZ_0  50.137787
# 42             KABA_0  50.876668
# 43            SEPET_0  51.020723
# 44         EMZIRMEK_0  51.529879
# 45      PROFESYONEL_1  51.575261
# 46            DÜŞÜK_2  51.757582
# 47         EL ÖPMEK_2  52.330273
# 48        İMZALAMAK_0  52.413665
# 49           BINMEK_1  52.595622

# %%
obj_1[:,0]
# Out:
# array([0.6155439669161669, 0.5474618526299653, 0.4762488430628112,
#        0.4068908364287412, 0.35035528325339715, 0.31001180108910603,
#        0.28434043784723223, 0.2747569869370229, 0.28035554705269106,
#        0.3203169361684198, 0.3494530959468264, 0.37306816584913594,
#        0.3826706593965666, 0.38287590105842106, 0.37247900335771095,
#        0.35055987205028266, 0.3190332655227857, 0.2847169720661499,
#        0.2593015129932318, 0.2560790688576122, 0.2710126240638043,
#        0.32011934611499954, 0.36028722126861445, 0.39191978333978855,
#        0.4145062600298068, 0.4242517735084594, 0.4455645599477763,
#        0.4925675761147404, 0.5648264618828559, 0.6195748872629941],
#       dtype=object)

# %% [markdown]
# ## Crawl TID Sözlük

# %%
(obj_1.shape, obj_2[:-2].shape)
# Out:
# ((30, 52), (30, 52))
